# %%
pip install geopandas
# Out:
# ...
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\HP\Desktop\projects\MatPlotLib_Tutorial\venv\Lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\Users\HP\Desktop\projects\MatPlotLib_Tutorial\venv\Lib\site-packages\pip\_vendor\urllib3\response.py", line 561, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\Desktop\projects\MatPlotLib_Tutorial\venv\Lib\site-packages\pip\_vendor\urllib3\response.py", line 527, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\Desktop\projects\MatPlotLib_Tutorial\venv\Lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 90, in read
#     data = self.__fp.read(amt)
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\.pyenv\pyenv-win\versions\3.11.0\Lib\http\client.py", line 465, in read
# ...
